# %%
import torch

print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# True
# Tesla T4

# %%
# !pip install --upgrade --no-cache-dir gdown
# !gdown 1SZZrpCgW8fI85m-_RpCygNuapWH3l0Vj
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.13/dist-packages (5.2.2)
# Collecting gdown
#   Downloading gdown-6.4.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.13/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from gdown) (3.32.5)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.13/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.13/dist-packages (from gdown) (4.67.3)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.13/dist-packages (from gdown) (2.5.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4->gdown) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4->gdown) (4.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests[socks]->gdown) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests[socks]->gdown) (3.19)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests[socks]->gdown) (2026.7.22)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.13/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading gdown-6.4.0-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 24.5 MB/s eta 0:00:00
# Installing collected packages: gdown
#   Attempting uninstall: gdown
#     Found existing installation: gdown 5.2.2
#     Uninstalling gdown-5.2.2:
#       Successfully uninstalled gdown-5.2.2
# Successfully installed gdown-6.4.0
# Downloading...
# From (original): https://drive.google.com/uc?id=1SZZrpCgW8fI85m-_RpCygNuapWH3l0Vj
# From (redirected): https://drive.google.com/uc?id=1SZZrpCgW8fI85m-_RpCygNuapWH3l0Vj&confirm=t&uuid=78d024b2-a0ab-49b8-b8dd-f5f744772430
# To: /content/archive.zip
# 100% 27.6M/27.6M [00:00<00:00, 46.1MB/s]

# %% [markdown]
# #1) Setup

# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 25.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 kB 3.1 MB/s eta 0:00:00

# %%
import os
import shutil
import random
import xml.etree.ElementTree as ET
from pathlib import Path

import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #2) Upload Dataset

# %%
# !unzip -q archive.zip -d /content/dataset

# %%
# !find /content/dataset -maxdepth 3 -type d
# Out:
# /content/dataset
# /content/dataset/NEU-DET
# /content/dataset/NEU-DET/ANNOTATIONS
# /content/dataset/NEU-DET/IMAGES

# %% [markdown]
# #3) Paths

# %%
ROOT = Path("/content/dataset/NEU-DET")
IMG_DIR = ROOT / "IMAGES"
ANN_DIR = ROOT / "ANNOTATIONS"

print("Images:", len(list(IMG_DIR.glob("*.jpg"))))
print("Annotations:", len(list(ANN_DIR.glob("*.xml"))))
# Out:
# Images: 1800
# Annotations: 1800

# %% [markdown]
# #4) Reading XML and displaying Bounding Box

# %%
def parse_voc_xml(xml_path):
    tree = ET.parse(xml_path)
    root = tree.getroot()

    filename = root.find("filename").text.strip()

    # Some XML files have filenames without extension
    if not filename.lower().endswith((".jpg", ".jpeg", ".png")):
        filename = filename + ".jpg"

    width = int(root.find("size/width").text)
    height = int(root.find("size/height").text)

    objects = []

    for obj in root.findall("object"):
        label = obj.find("name").text.strip()
        bbox = obj.find("bndbox")

        xmin = int(float(bbox.find("xmin").text))
        ymin = int(float(bbox.find("ymin").text))
        xmax = int(float(bbox.find("xmax").text))
        ymax = int(float(bbox.find("ymax").text))

        objects.append({
            "label": label,
            "bbox": [xmin, ymin, xmax, ymax]
        })

    return filename, width, height, objects

# %%
sample_xml = list(ANN_DIR.glob("*.xml"))[0]
filename, width, height, objects = parse_voc_xml(sample_xml)

img_path = IMG_DIR / filename
img = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)
img_rgb = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)

for obj in objects:
    xmin, ymin, xmax, ymax = obj["bbox"]
    label = obj["label"]
    cv2.rectangle(img_rgb, (xmin, ymin), (xmax, ymax), (255, 0, 0), 2)
    cv2.putText(img_rgb, label, (xmin, max(ymin - 5, 10)),
                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 1)

plt.figure(figsize=(5,5))
plt.imshow(img_rgb)
plt.axis("off")
plt.show()

# %% [markdown]
# #5) Classes

# %%
classes = set()

for xml_path in ANN_DIR.glob("*.xml"):
    _, _, _, objects = parse_voc_xml(xml_path)
    for obj in objects:
        classes.add(obj["label"])

classes = sorted(list(classes))
class_to_id = {cls: i for i, cls in enumerate(classes)}

print(classes)
print(class_to_id)
# Out:
# ['crazing', 'inclusion', 'patches', 'pitted_surface', 'rolled-in_scale', 'scratches']
# {'crazing': 0, 'inclusion': 1, 'patches': 2, 'pitted_surface': 3, 'rolled-in_scale': 4, 'scratches': 5}

# %% [markdown]
# #6) Convert XML to YOLO format

# %%
YOLO_ROOT = Path("/content/neu_yolo")
for split in ["train", "val", "test"]:
    (YOLO_ROOT / "images" / split).mkdir(parents=True, exist_ok=True)
    (YOLO_ROOT / "labels" / split).mkdir(parents=True, exist_ok=True)

# %%
xml_files = list(ANN_DIR.glob("*.xml"))
random.seed(42)
random.shuffle(xml_files)

n = len(xml_files)
train_files = xml_files[:int(0.7*n)]
val_files = xml_files[int(0.7*n):int(0.85*n)]
test_files = xml_files[int(0.85*n):]

splits = {
    "train": train_files,
    "val": val_files,
    "test": test_files
}

print(len(train_files), len(val_files), len(test_files))
# Out:
# 1260 270 270

# %%
def voc_to_yolo_bbox(bbox, img_w, img_h):
    xmin, ymin, xmax, ymax = bbox

    x_center = ((xmin + xmax) / 2) / img_w
    y_center = ((ymin + ymax) / 2) / img_h
    box_w = (xmax - xmin) / img_w
    box_h = (ymax - ymin) / img_h

    return x_center, y_center, box_w, box_h

# %%
for split, files in splits.items():
    for xml_path in files:
        filename, width, height, objects = parse_voc_xml(xml_path)

        src_img = IMG_DIR / filename
        dst_img = YOLO_ROOT / "images" / split / filename
        shutil.copy(src_img, dst_img)

        label_filename = Path(filename).stem + ".txt"
        dst_label = YOLO_ROOT / "labels" / split / label_filename

        with open(dst_label, "w") as f:
            for obj in objects:
                class_id = class_to_id[obj["label"]]
                x, y, w, h = voc_to_yolo_bbox(obj["bbox"], width, height)
                f.write(f"{class_id} {x:.6f} {y:.6f} {w:.6f} {h:.6f}\n")

# %% [markdown]
# #7) Creating a YAML file for YOLOv8

# %%
yaml_content = f"""
path: {YOLO_ROOT}
train: images/train
val: images/val
test: images/test

names:
"""

for i, cls in enumerate(classes):
    yaml_content += f"  {i}: {cls}\n"

yaml_path = YOLO_ROOT / "neu_det.yaml"

with open(yaml_path, "w") as f:
    f.write(yaml_content)

print(yaml_content)
# Out:
# path: /content/neu_yolo
# train: images/train
# val: images/val
# test: images/test
#
# names:
#   0: crazing
#   1: inclusion
#   2: patches
#   3: pitted_surface
#   4: rolled-in_scale
#   5: scratches

# %% [markdown]
# #8) YOLOv8n training

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

results = model.train(
    data=str(yaml_path),
    epochs=50,
    imgsz=200,
    batch=16,
    patience=10,
    project="/content/runs",
    name="neu_yolov8n"
)
# Out:
# Creating new Ultralytics Settings v0.0.8 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/usage/settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 95.6MB/s 0.1s
# Ultralytics 8.4.157 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/neu_yolo/neu_det.yaml, degrees=0.0, deterministic=True, device=, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=200, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=neu_yolov8n, nbs=64, nms=None, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/runs, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/neu_yolov8n, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 21.0MB/s 0.0s
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752482  ultralytics.nn.modules.head.Detect           [6, 16, None, [64, 128, 256]]
# Model summary: 129 layers, 3,012,018 parameters, 3,012,002 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# WARNING ⚠️ imgsz=[200] must be multiple of max stride 32, updating to [224]
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: downloading yolo26n.pt for AMP checks (one-time, not used for training)...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'weights/yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 85.1MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 649.4±325.2 MB/s, size: 19.3 KB)
# train: Scanning /content/neu_yolo/labels/train... 1260 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1260/1260 2.0Kit/s 0.6s
# train: /content/neu_yolo/images/train/crazing_120.jpg: 1 duplicate labels removed
# train: /content/neu_yolo/images/train/inclusion_62.jpg: 1 duplicate labels removed
# train: /content/neu_yolo/images/train/patches_198.jpg: 1 duplicate labels removed
# train: New cache created: /content/neu_yolo/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 215.6±88.8 MB/s, size: 14.1 KB)
# val: Scanning /content/neu_yolo/labels/val... 270 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 270/270 1.1Kit/s 0.3s
# val: New cache created: /content/neu_yolo/labels/val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to /content/runs/neu_yolov8n/labels.jpg...
# Using 1260 train, 270 val images for fraction=1.0 at imgsz=224
# Using 2 dataloader workers
# Logging results to /content/runs/neu_yolov8n
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50     0.354G      1.922      3.355      1.667         50        224: 100% ━━━━━━━━━━━━ 79/79 6.7it/s 11.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 6.8it/s 1.3s
#                    all        270        624      0.581      0.216      0.284      0.134
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50     0.377G      1.837      2.154      1.574         55        224: 100% ━━━━━━━━━━━━ 79/79 9.5it/s 8.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.2it/s 1.1s
#                    all        270        624      0.326      0.594      0.419      0.202
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50     0.377G      1.772      1.906      1.579         41        224: 100% ━━━━━━━━━━━━ 79/79 10.9it/s 7.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 5.6it/s 1.6s
#                    all        270        624       0.29      0.532      0.366      0.166
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50     0.377G      1.696       1.79      1.521         42        224: 100% ━━━━━━━━━━━━ 79/79 11.2it/s 7.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.3it/s 1.1s
#                    all        270        624       0.45      0.551      0.527      0.254
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50     0.377G      1.678      1.745       1.51         46        224: 100% ━━━━━━━━━━━━ 79/79 9.7it/s 8.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.3it/s 1.1s
#                    all        270        624      0.672      0.487      0.526      0.278
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50     0.377G      1.648      1.696      1.511         52        224: 100% ━━━━━━━━━━━━ 79/79 11.0it/s 7.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 5.6it/s 1.6s
#                    all        270        624      0.413      0.621      0.563      0.284
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50     0.377G      1.613      1.625       1.47         67        224: 100% ━━━━━━━━━━━━ 79/79 11.3it/s 7.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.2it/s 1.1s
#                    all        270        624      0.473      0.588      0.534      0.254
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50     0.377G      1.595      1.597      1.458         42        224: 100% ━━━━━━━━━━━━ 79/79 9.6it/s 8.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.1it/s 1.1s
#                    all        270        624      0.611      0.551      0.617      0.314
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50     0.377G      1.594        1.6      1.471         49        224: 100% ━━━━━━━━━━━━ 79/79 10.1it/s 7.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 5.9it/s 1.5s
#                    all        270        624      0.766      0.493      0.594      0.323
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50     0.377G      1.574      1.585      1.456         65        224: 100% ━━━━━━━━━━━━ 79/79 11.6it/s 6.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.4it/s 1.1s
#                    all        270        624      0.787      0.532      0.654      0.352
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50     0.377G      1.536      1.545      1.421         65        224: 100% ━━━━━━━━━━━━ 79/79 9.6it/s 8.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.4it/s 1.1s
#                    all        270        624      0.527       0.51      0.536      0.278
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50     0.377G      1.552      1.529       1.43         63        224: 100% ━━━━━━━━━━━━ 79/79 9.9it/s 7.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 6.6it/s 1.4s
#                    all        270        624      0.729      0.552       0.62      0.341
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50     0.377G      1.531      1.521      1.416         47        224: 100% ━━━━━━━━━━━━ 79/79 11.4it/s 6.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.2it/s 1.1s
#                    all        270        624      0.718      0.511      0.599      0.318
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50     0.377G      1.514      1.482      1.411         45        224: 100% ━━━━━━━━━━━━ 79/79 9.6it/s 8.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.4it/s 1.1s
#                    all        270        624      0.705      0.507      0.562      0.298
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50     0.377G      1.526      1.488      1.405         45        224: 100% ━━━━━━━━━━━━ 79/79 9.7it/s 8.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.3it/s 1.1s
#                    all        270        624      0.756      0.567      0.663      0.353
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50     0.377G        1.5      1.479      1.408         61        224: 100% ━━━━━━━━━━━━ 79/79 11.4it/s 6.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.2it/s 1.1s
#                    all        270        624      0.558      0.655      0.613      0.332
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50     0.377G      1.495      1.464       1.39         73        224: 100% ━━━━━━━━━━━━ 79/79 9.7it/s 8.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.2it/s 1.1s
#                    all        270        624      0.601       0.55      0.604      0.328
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50     0.377G      1.502      1.465      1.413         40        224: 100% ━━━━━━━━━━━━ 79/79 9.4it/s 8.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.4it/s 1.1s
#                    all        270        624      0.677      0.552      0.594      0.311
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50     0.377G      1.492      1.427      1.405         46        224: 100% ━━━━━━━━━━━━ 79/79 11.4it/s 6.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.0it/s 1.1s
#                    all        270        624      0.579      0.644      0.658      0.367
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50     0.377G      1.494      1.404      1.392         73        224: 100% ━━━━━━━━━━━━ 79/79 9.7it/s 8.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.3it/s 1.1s
#                    all        270        624       0.56       0.61      0.633      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50     0.377G      1.468      1.386      1.376         47        224: 100% ━━━━━━━━━━━━ 79/79 9.6it/s 8.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.2it/s 1.1s
#                    all        270        624      0.789      0.538      0.653      0.374
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50     0.377G      1.471      1.405      1.377         56        224: 100% ━━━━━━━━━━━━ 79/79 11.4it/s 6.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 7.2it/s 1.2s
#                    all        270        624       0.78      0.561      0.691      0.383
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50     0.377G      1.453      1.387      1.375         54        224: 100% ━━━━━━━━━━━━ 79/79 9.9it/s 8.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.3it/s 1.1s
#                    all        270        624      0.773      0.554      0.655      0.358
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50     0.377G      1.434      1.344      1.365         41        224: 100% ━━━━━━━━━━━━ 79/79 9.6it/s 8.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.4it/s 1.1s
#                    all        270        624      0.628      0.614      0.656      0.358
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50     0.377G      1.427      1.348      1.367         72        224: 100% ━━━━━━━━━━━━ 79/79 11.4it/s 6.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 6.2it/s 1.5s
#                    all        270        624      0.722      0.548      0.664       0.37
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50     0.377G      1.424      1.364      1.359         63        224: 100% ━━━━━━━━━━━━ 79/79 10.3it/s 7.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.2it/s 1.1s
#                    all        270        624      0.706      0.599      0.686      0.375
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50     0.377G       1.44      1.357      1.369         66        224: 100% ━━━━━━━━━━━━ 79/79 9.6it/s 8.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.7it/s 1.0s
#                    all        270        624      0.637      0.687      0.708      0.402
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50     0.377G      1.416      1.311      1.358         67        224: 100% ━━━━━━━━━━━━ 79/79 11.3it/s 7.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 5.6it/s 1.6s
#                    all        270        624      0.601      0.678      0.696      0.391
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50     0.377G      1.413      1.296       1.34         65        224: 100% ━━━━━━━━━━━━ 79/79 10.7it/s 7.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.3it/s 1.1s
#                    all        270        624      0.588       0.67      0.697      0.394
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50     0.377G      1.402      1.304      1.346         44        224: 100% ━━━━━━━━━━━━ 79/79 9.7it/s 8.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.3it/s 1.1s
#                    all        270        624       0.57      0.672       0.66      0.379
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50     0.377G      1.413      1.288      1.346         62        224: 100% ━━━━━━━━━━━━ 79/79 11.0it/s 7.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 5.3it/s 1.7s
#                    all        270        624      0.703      0.636      0.708      0.404
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50     0.377G      1.404      1.315       1.34         55        224: 100% ━━━━━━━━━━━━ 79/79 11.5it/s 6.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.4it/s 1.1s
#                    all        270        624      0.728      0.653      0.743      0.422
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50     0.377G      1.395      1.301      1.346         47        224: 100% ━━━━━━━━━━━━ 79/79 9.5it/s 8.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.3it/s 1.1s
#                    all        270        624      0.645       0.65      0.686       0.38
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50     0.377G      1.376      1.289      1.337         50        224: 100% ━━━━━━━━━━━━ 79/79 10.7it/s 7.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 5.9it/s 1.5s
#                    all        270        624      0.679      0.668      0.744      0.433
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50     0.377G      1.389       1.27      1.344         51        224: 100% ━━━━━━━━━━━━ 79/79 11.4it/s 6.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.1it/s 1.1s
#                    all        270        624       0.67      0.668      0.728      0.429
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50     0.377G      1.357      1.229      1.319         56        224: 100% ━━━━━━━━━━━━ 79/79 9.4it/s 8.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.4it/s 1.1s
#                    all        270        624      0.603      0.698      0.727      0.421
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50     0.377G       1.36      1.257      1.316         53        224: 100% ━━━━━━━━━━━━ 79/79 10.3it/s 7.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 6.0it/s 1.5s
#                    all        270        624      0.604      0.706      0.712      0.413
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50     0.377G       1.36      1.246      1.326         64        224: 100% ━━━━━━━━━━━━ 79/79 11.4it/s 6.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.5it/s 1.1s
#                    all        270        624      0.654      0.685      0.715      0.406
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50     0.377G      1.368      1.242      1.323         72        224: 100% ━━━━━━━━━━━━ 79/79 9.5it/s 8.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.4it/s 1.1s
#                    all        270        624      0.679      0.633      0.694      0.396
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50     0.377G      1.376      1.246      1.324         75        224: 100% ━━━━━━━━━━━━ 79/79 9.9it/s 8.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 7.2it/s 1.2s
#                    all        270        624      0.677      0.634      0.713      0.405
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50     0.377G      1.384      1.322      1.365         25        224: 100% ━━━━━━━━━━━━ 79/79 11.1it/s 7.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.4it/s 1.1s
#                    all        270        624      0.674      0.638      0.716       0.42
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50     0.377G      1.343      1.243      1.344         21        224: 100% ━━━━━━━━━━━━ 79/79 10.2it/s 7.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.1it/s 1.1s
#                    all        270        624      0.715      0.589      0.713      0.416
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50     0.377G       1.32      1.197      1.335         40        224: 100% ━━━━━━━━━━━━ 79/79 10.3it/s 7.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 7.7it/s 1.2s
#                    all        270        624       0.69      0.656      0.712      0.417
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50     0.377G      1.302      1.179      1.327         23        224: 100% ━━━━━━━━━━━━ 79/79 12.5it/s 6.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.2it/s 1.1s
#                    all        270        624      0.665      0.692      0.741      0.436
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50     0.377G      1.285      1.169      1.323         30        224: 100% ━━━━━━━━━━━━ 79/79 10.3it/s 7.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.2it/s 1.1s
#                    all        270        624      0.645       0.68      0.715      0.422
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50     0.377G      1.273      1.149      1.312         24        224: 100% ━━━━━━━━━━━━ 79/79 11.4it/s 7.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 5.9it/s 1.5s
#                    all        270        624       0.67      0.676       0.74       0.44
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50     0.377G      1.278      1.147      1.307         22        224: 100% ━━━━━━━━━━━━ 79/79 12.2it/s 6.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.5it/s 1.1s
#                    all        270        624      0.672      0.697      0.742      0.441
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50     0.377G      1.283      1.124      1.303         28        224: 100% ━━━━━━━━━━━━ 79/79 10.3it/s 7.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.3it/s 1.1s
#                    all        270        624      0.687      0.699      0.743      0.445
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50     0.377G      1.275      1.133        1.3         25        224: 100% ━━━━━━━━━━━━ 79/79 12.1it/s 6.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 6.1it/s 1.5s
#                    all        270        624      0.698      0.707      0.745      0.448
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50     0.377G      1.265      1.123        1.3         35        224: 100% ━━━━━━━━━━━━ 79/79 11.3it/s 7.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 8.4it/s 1.1s
#                    all        270        624      0.681      0.718      0.753      0.451
#
# 50 epochs completed in 0.128 hours.
# Optimizer stripped from /content/runs/neu_yolov8n/weights/last.pt, 6.2MB
# Optimizer stripped from /content/runs/neu_yolov8n/weights/best.pt, 6.2MB
#
# Validating /content/runs/neu_yolov8n/weights/best.pt...
# Ultralytics 8.4.157 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 72 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.0it/s 2.2s
#                    all        270        624       0.68      0.718      0.753      0.451
#                crazing         35         77      0.656      0.325      0.435      0.178
#              inclusion         65        176      0.644      0.773      0.807      0.437
#                patches         41        108      0.831      0.963      0.966      0.667
#         pitted_surface         49         72      0.717      0.722      0.784      0.565
#        rolled-in_scale         49        100       0.51       0.58      0.572      0.288
#              scratches         49         91       0.72      0.945      0.951      0.568
# Speed: 0.2ms preprocess, 1.9ms inference, 0.0ms loss, 3.3ms postprocess per image
# Results saved to /content/runs/neu_yolov8n

# %% [markdown]
# #9) Evaluation on the test

# %%
model = YOLO("/content/runs/neu_yolov8n/weights/best.pt")

metrics = model.val(
    data=str(yaml_path),
    split="test",
    imgsz=200
)
# Out:
# WARNING ⚠️ imgsz=[200] must be multiple of max stride 32, updating to [224]
# Ultralytics 8.4.157 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 72 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 462.6±247.8 MB/s, size: 10.3 KB)
# val: Scanning /content/neu_yolo/labels/test... 270 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 270/270 2.1Kit/s 0.1s
# val: New cache created: /content/neu_yolo/labels/test.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 8.0it/s 2.1s
#                    all        270        615      0.647      0.724      0.725      0.428
#                crazing         45        102      0.553      0.265      0.371      0.151
#              inclusion         57        143      0.617      0.825      0.828      0.473
#                patches         60        154      0.767       0.96      0.936      0.587
#         pitted_surface         39         54      0.752      0.833      0.842      0.507
#        rolled-in_scale         34         71       0.42      0.493       0.42      0.202
#              scratches         55         91      0.771      0.967      0.952      0.648
# Speed: 0.4ms preprocess, 1.5ms inference, 0.0ms loss, 2.8ms postprocess per image
# Results saved to /content/runs/detect/val

# %% [markdown]
# #10) Inference on multiple images

# %%
test_images = list((YOLO_ROOT / "images" / "test").glob("*.jpg"))[:5]

for img_path in test_images:
    results = model.predict(
        source=str(img_path),
        imgsz=200,
        conf=0.25
    )

    plotted = results[0].plot()
    plt.figure(figsize=(5,5))
    plt.imshow(cv2.cvtColor(plotted, cv2.COLOR_BGR2RGB))
    plt.axis("off")
    plt.show()
# Out:
# WARNING ⚠️ imgsz=[200] must be multiple of max stride 32, updating to [224]
# image 1/1 /content/neu_yolo/images/test/patches_64.jpg: 224x224 1 patches, 6.2ms
# Speed: 0.6ms preprocess, 6.2ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
# WARNING ⚠️ imgsz=[200] must be multiple of max stride 32, updating to [224]
# image 1/1 /content/neu_yolo/images/test/inclusion_219.jpg: 224x224 3 inclusions, 10.9ms
# Speed: 1.0ms preprocess, 10.9ms inference, 4.4ms postprocess per image at shape (1, 3, 224, 224)
# WARNING ⚠️ imgsz=[200] must be multiple of max stride 32, updating to [224]
# image 1/1 /content/neu_yolo/images/test/scratches_199.jpg: 224x224 2 scratchess, 11.8ms
# Speed: 1.3ms preprocess, 11.8ms inference, 3.7ms postprocess per image at shape (1, 3, 224, 224)
# WARNING ⚠️ imgsz=[200] must be multiple of max stride 32, updating to [224]
# image 1/1 /content/neu_yolo/images/test/inclusion_16.jpg: 224x224 3 inclusions, 12.0ms
# Speed: 2.9ms preprocess, 12.0ms inference, 2.2ms postprocess per image at shape (1, 3, 224, 224)
# WARNING ⚠️ imgsz=[200] must be multiple of max stride 32, updating to [224]
# image 1/1 /content/neu_yolo/images/test/rolled-in_scale_224.jpg: 224x224 3 rolled-in_scales, 22.1ms
# Speed: 1.0ms preprocess, 22.1ms inference, 2.5ms postprocess per image at shape (1, 3, 224, 224)

# %%
print(metrics.box.map)
print(metrics.box.map50)
print(metrics.box.mp)
print(metrics.box.mr)
# Out:
# 0.4280633907157194
# 0.7247612287673255
# 0.6465159200759144
# 0.723846932315872

# %% [markdown]
# #11) Save results

# %%
results_summary = {
    "model": "YOLOv8n",
    "mAP50": metrics.box.map50,
    "mAP50_95": metrics.box.map,
    "precision": metrics.box.mp,
    "recall": metrics.box.mr
}

results_summary
# Out:
# {'model': 'YOLOv8n',
#  'mAP50': np.float64(0.7247612287673255),
#  'mAP50_95': np.float64(0.4280633907157194),
#  'precision': np.float64(0.6465159200759144),
#  'recall': np.float64(0.723846932315872)}

# %%
output_dir = "/content/yolo_predictions"

results = model.predict(
    source=str(YOLO_ROOT / "images" / "test"),
    imgsz=200,
    conf=0.25,
    save=True,
    project=output_dir,
    name="predictions"
)
# Out:
# WARNING ⚠️ imgsz=[200] must be multiple of max stride 32, updating to [224]
# image 1/270 /content/neu_yolo/images/test/crazing_108.jpg: 224x224 3 crazings, 10.5ms
# image 2/270 /content/neu_yolo/images/test/crazing_113.jpg: 224x224 1 crazing, 8.9ms
# image 3/270 /content/neu_yolo/images/test/crazing_119.jpg: 224x224 1 crazing, 9.9ms
# image 4/270 /content/neu_yolo/images/test/crazing_122.jpg: 224x224 1 crazing, 9.0ms
# image 5/270 /content/neu_yolo/images/test/crazing_134.jpg: 224x224 2 crazings, 9.0ms
# image 6/270 /content/neu_yolo/images/test/crazing_142.jpg: 224x224 (no detections), 8.9ms
# image 7/270 /content/neu_yolo/images/test/crazing_145.jpg: 224x224 2 crazings, 7.0ms
# image 8/270 /content/neu_yolo/images/test/crazing_149.jpg: 224x224 2 crazings, 9.1ms
# image 9/270 /content/neu_yolo/images/test/crazing_152.jpg: 224x224 (no detections), 10.9ms
# image 10/270 /content/neu_yolo/images/test/crazing_165.jpg: 224x224 2 crazings, 9.5ms
# image 11/270 /content/neu_yolo/images/test/crazing_166.jpg: 224x224 2 crazings, 9.4ms
# image 12/270 /content/neu_yolo/images/test/crazing_172.jpg: 224x224 1 crazing, 9.3ms
# image 13/270 /content/neu_yolo/images/test/crazing_18.jpg: 224x224 1 crazing, 10.6ms
# image 14/270 /content/neu_yolo/images/test/crazing_2.jpg: 224x224 (no detections), 10.6ms
# image 15/270 /content/neu_yolo/images/test/crazing_201.jpg: 224x224 (no detections), 9.4ms
# image 16/270 /content/neu_yolo/images/test/crazing_205.jpg: 224x224 1 crazing, 11.4ms
# image 17/270 /content/neu_yolo/images/test/crazing_214.jpg: 224x224 1 crazing, 10.8ms
# image 18/270 /content/neu_yolo/images/test/crazing_220.jpg: 224x224 1 crazing, 9.8ms
# image 19/270 /content/neu_yolo/images/test/crazing_23.jpg: 224x224 (no detections), 9.0ms
# image 20/270 /content/neu_yolo/images/test/crazing_232.jpg: 224x224 3 crazings, 8.7ms
# image 21/270 /content/neu_yolo/images/test/crazing_237.jpg: 224x224 1 crazing, 14.5ms
# image 22/270 /content/neu_yolo/images/test/crazing_238.jpg: 224x224 (no detections), 10.2ms
# image 23/270 /content/neu_yolo/images/test/crazing_240.jpg: 224x224 3 crazings, 8.6ms
# image 24/270 /content/neu_yolo/images/test/crazing_249.jpg: 224x224 1 crazing, 8.6ms
# image 25/270 /content/neu_yolo/images/test/crazing_250.jpg: 224x224 2 crazings, 8.3ms
# image 26/270 /content/neu_yolo/images/test/crazing_254.jpg: 224x224 2 crazings, 8.3ms
# image 27/270 /content/neu_yolo/images/test/crazing_26.jpg: 224x224 1 crazing, 8.3ms
# image 28/270 /content/neu_yolo/images/test/crazing_269.jpg: 224x224 2 crazings, 8.5ms
# image 29/270 /content/neu_yolo/images/test/crazing_272.jpg: 224x224 2 crazings, 7.9ms
# image 30/270 /content/neu_yolo/images/test/crazing_277.jpg: 224x224 2 crazings, 8.6ms
# image 31/270 /content/neu_yolo/images/test/crazing_28.jpg: 224x224 4 crazings, 8.1ms
# image 32/270 /content/neu_yolo/images/test/crazing_284.jpg: 224x224 2 crazings, 8.3ms
# image 33/270 /content/neu_yolo/images/test/crazing_285.jpg: 224x224 (no detections), 7.7ms
# image 34/270 /content/neu_yolo/images/test/crazing_289.jpg: 224x224 (no detections), 9.9ms
# image 35/270 /content/neu_yolo/images/test/crazing_294.jpg: 224x224 1 crazing, 7.6ms
# image 36/270 /content/neu_yolo/images/test/crazing_296.jpg: 224x224 2 crazings, 7.7ms
# image 37/270 /content/neu_yolo/images/test/crazing_300.jpg: 224x224 2 crazings, 8.3ms
# image 38/270 /content/neu_yolo/images/test/crazing_41.jpg: 224x224 (no detections), 8.2ms
# image 39/270 /content/neu_yolo/images/test/crazing_59.jpg: 224x224 (no detections), 8.8ms
# image 40/270 /content/neu_yolo/images/test/crazing_63.jpg: 224x224 (no detections), 8.2ms
# image 41/270 /content/neu_yolo/images/test/crazing_65.jpg: 224x224 2 crazings, 10.6ms
# image 42/270 /content/neu_yolo/images/test/crazing_79.jpg: 224x224 2 crazings, 7.7ms
# image 43/270 /content/neu_yolo/images/test/crazing_88.jpg: 224x224 1 crazing, 10.1ms
# image 44/270 /content/neu_yolo/images/test/crazing_89.jpg: 224x224 1 crazing, 7.9ms
# image 45/270 /content/neu_yolo/images/test/crazing_91.jpg: 224x224 1 crazing, 7.1ms
# image 46/270 /content/neu_yolo/images/test/inclusion_1.jpg: 224x224 6 inclusions, 8.4ms
# image 47/270 /content/neu_yolo/images/test/inclusion_104.jpg: 224x224 3 inclusions, 12.9ms
# image 48/270 /content/neu_yolo/images/test/inclusion_11.jpg: 224x224 3 inclusions, 9.6ms
# image 49/270 /content/neu_yolo/images/test/inclusion_126.jpg: 224x224 6 inclusions, 7.8ms
# image 50/270 /content/neu_yolo/images/test/inclusion_130.jpg: 224x224 8 inclusions, 8.8ms
# image 51/270 /content/neu_yolo/images/test/inclusion_134.jpg: 224x224 2 inclusions, 7.4ms
# image 52/270 /content/neu_yolo/images/test/inclusion_153.jpg: 224x224 5 inclusions, 8.7ms
# image 53/270 /content/neu_yolo/images/test/inclusion_16.jpg: 224x224 3 inclusions, 7.7ms
# image 54/270 /content/neu_yolo/images/test/inclusion_17.jpg: 224x224 5 inclusions, 7.5ms
# image 55/270 /content/neu_yolo/images/test/inclusion_192.jpg: 224x224 4 inclusions, 8.7ms
# image 56/270 /content/neu_yolo/images/test/inclusion_201.jpg: 224x224 1 inclusion, 7.1ms
# image 57/270 /content/neu_yolo/images/test/inclusion_204.jpg: 224x224 2 inclusions, 7.3ms
# image 58/270 /content/neu_yolo/images/test/inclusion_205.jpg: 224x224 2 inclusions, 8.6ms
# image 59/270 /content/neu_yolo/images/test/inclusion_208.jpg: 224x224 2 inclusions, 7.6ms
# image 60/270 /content/neu_yolo/images/test/inclusion_214.jpg: 224x224 2 inclusions, 7.4ms
# image 61/270 /content/neu_yolo/images/test/inclusion_216.jpg: 224x224 2 inclusions, 7.5ms
# image 62/270 /content/neu_yolo/images/test/inclusion_218.jpg: 224x224 3 inclusions, 6.9ms
# image 63/270 /content/neu_yolo/images/test/inclusion_219.jpg: 224x224 3 inclusions, 7.7ms
# image 64/270 /content/neu_yolo/images/test/inclusion_224.jpg: 224x224 1 inclusion, 7.1ms
# image 65/270 /content/neu_yolo/images/test/inclusion_237.jpg: 224x224 5 inclusions, 7.8ms
# image 66/270 /content/neu_yolo/images/test/inclusion_239.jpg: 224x224 1 inclusion, 7.3ms
# image 67/270 /content/neu_yolo/images/test/inclusion_241.jpg: 224x224 5 inclusions, 9.2ms
# image 68/270 /content/neu_yolo/images/test/inclusion_245.jpg: 224x224 5 inclusions, 7.8ms
# image 69/270 /content/neu_yolo/images/test/inclusion_25.jpg: 224x224 5 inclusions, 7.6ms
# image 70/270 /content/neu_yolo/images/test/inclusion_263.jpg: 224x224 2 inclusions, 8.0ms
# image 71/270 /content/neu_yolo/images/test/inclusion_272.jpg: 224x224 4 inclusions, 9.4ms
# image 72/270 /content/neu_yolo/images/test/inclusion_273.jpg: 224x224 4 inclusions, 9.4ms
# image 73/270 /content/neu_yolo/images/test/inclusion_276.jpg: 224x224 3 inclusions, 10.0ms
# image 74/270 /content/neu_yolo/images/test/inclusion_283.jpg: 224x224 1 inclusion, 8.5ms
# image 75/270 /content/neu_yolo/images/test/inclusion_285.jpg: 224x224 2 inclusions, 7.9ms
# image 76/270 /content/neu_yolo/images/test/inclusion_289.jpg: 224x224 4 inclusions, 9.1ms
# image 77/270 /content/neu_yolo/images/test/inclusion_3.jpg: 224x224 4 inclusions, 9.0ms
# image 78/270 /content/neu_yolo/images/test/inclusion_36.jpg: 224x224 5 inclusions, 8.3ms
# image 79/270 /content/neu_yolo/images/test/inclusion_51.jpg: 224x224 1 inclusion, 7.8ms
# image 80/270 /content/neu_yolo/images/test/inclusion_53.jpg: 224x224 1 inclusion, 7.6ms
# image 81/270 /content/neu_yolo/images/test/inclusion_59.jpg: 224x224 7 inclusions, 7.5ms
# image 82/270 /content/neu_yolo/images/test/inclusion_61.jpg: 224x224 4 inclusions, 8.5ms
# image 83/270 /content/neu_yolo/images/test/inclusion_67.jpg: 224x224 7 inclusions, 7.4ms
# image 84/270 /content/neu_yolo/images/test/inclusion_7.jpg: 224x224 2 inclusions, 8.4ms
# image 85/270 /content/neu_yolo/images/test/inclusion_71.jpg: 224x224 2 inclusions, 7.4ms
# image 86/270 /content/neu_yolo/images/test/inclusion_75.jpg: 224x224 5 inclusions, 7.9ms
# image 87/270 /content/neu_yolo/images/test/inclusion_88.jpg: 224x224 9 inclusions, 9.0ms
# image 88/270 /content/neu_yolo/images/test/inclusion_91.jpg: 224x224 6 inclusions, 12.0ms
# image 89/270 /content/neu_yolo/images/test/patches_106.jpg: 224x224 1 patches, 11.6ms
# image 90/270 /content/neu_yolo/images/test/patches_109.jpg: 224x224 3 patchess, 9.3ms
# image 91/270 /content/neu_yolo/images/test/patches_114.jpg: 224x224 6 patchess, 10.4ms
# image 92/270 /content/neu_yolo/images/test/patches_115.jpg: 224x224 5 patchess, 12.7ms
# image 93/270 /content/neu_yolo/images/test/patches_121.jpg: 224x224 1 patches, 11.1ms
# image 94/270 /content/neu_yolo/images/test/patches_124.jpg: 224x224 5 patchess, 12.4ms
# image 95/270 /content/neu_yolo/images/test/patches_128.jpg: 224x224 6 patchess, 10.4ms
# image 96/270 /content/neu_yolo/images/test/patches_130.jpg: 224x224 4 patchess, 10.2ms
# image 97/270 /content/neu_yolo/images/test/patches_138.jpg: 224x224 4 patchess, 9.3ms
# image 98/270 /content/neu_yolo/images/test/patches_144.jpg: 224x224 2 patchess, 10.8ms
# image 99/270 /content/neu_yolo/images/test/patches_145.jpg: 224x224 4 patchess, 10.2ms
# image 100/270 /content/neu_yolo/images/test/patches_149.jpg: 224x224 3 patchess, 12.2ms
# image 101/270 /content/neu_yolo/images/test/patches_16.jpg: 224x224 3 patchess, 11.1ms
# image 102/270 /content/neu_yolo/images/test/patches_170.jpg: 224x224 1 patches, 8.8ms
# image 103/270 /content/neu_yolo/images/test/patches_174.jpg: 224x224 3 patchess, 8.9ms
# image 104/270 /content/neu_yolo/images/test/patches_181.jpg: 224x224 7 patchess, 15.7ms
# image 105/270 /content/neu_yolo/images/test/patches_182.jpg: 224x224 3 patchess, 12.9ms
# image 106/270 /content/neu_yolo/images/test/patches_194.jpg: 224x224 3 patchess, 8.6ms
# image 107/270 /content/neu_yolo/images/test/patches_2.jpg: 224x224 3 patchess, 8.6ms
# image 108/270 /content/neu_yolo/images/test/patches_200.jpg: 224x224 3 patchess, 7.8ms
# image 109/270 /content/neu_yolo/images/test/patches_204.jpg: 224x224 3 patchess, 8.2ms
# image 110/270 /content/neu_yolo/images/test/patches_211.jpg: 224x224 5 patchess, 8.8ms
# image 111/270 /content/neu_yolo/images/test/patches_213.jpg: 224x224 3 patchess, 8.0ms
# image 112/270 /content/neu_yolo/images/test/patches_218.jpg: 224x224 6 patchess, 7.2ms
# image 113/270 /content/neu_yolo/images/test/patches_228.jpg: 224x224 1 inclusion, 5 patchess, 8.6ms
# image 114/270 /content/neu_yolo/images/test/patches_233.jpg: 224x224 5 patchess, 11.5ms
# image 115/270 /content/neu_yolo/images/test/patches_235.jpg: 224x224 1 inclusion, 3 patchess, 9.3ms
# image 116/270 /content/neu_yolo/images/test/patches_246.jpg: 224x224 6 patchess, 10.1ms
# image 117/270 /content/neu_yolo/images/test/patches_247.jpg: 224x224 3 patchess, 8.3ms
# image 118/270 /content/neu_yolo/images/test/patches_25.jpg: 224x224 5 patchess, 7.9ms
# image 119/270 /content/neu_yolo/images/test/patches_250.jpg: 224x224 5 patchess, 7.5ms
# image 120/270 /content/neu_yolo/images/test/patches_258.jpg: 224x224 3 patchess, 8.6ms
# image 121/270 /content/neu_yolo/images/test/patches_260.jpg: 224x224 2 inclusions, 1 patches, 9.4ms
# image 122/270 /content/neu_yolo/images/test/patches_261.jpg: 224x224 4 patchess, 8.0ms
# image 123/270 /content/neu_yolo/images/test/patches_266.jpg: 224x224 4 patchess, 7.0ms
# image 124/270 /content/neu_yolo/images/test/patches_270.jpg: 224x224 2 patchess, 8.4ms
# image 125/270 /content/neu_yolo/images/test/patches_277.jpg: 224x224 6 patchess, 7.9ms
# image 126/270 /content/neu_yolo/images/test/patches_283.jpg: 224x224 5 patchess, 7.9ms
# image 127/270 /content/neu_yolo/images/test/patches_284.jpg: 224x224 3 patchess, 7.3ms
# image 128/270 /content/neu_yolo/images/test/patches_296.jpg: 224x224 4 patchess, 8.5ms
# image 129/270 /content/neu_yolo/images/test/patches_31.jpg: 224x224 5 patchess, 7.9ms
# image 130/270 /content/neu_yolo/images/test/patches_34.jpg: 224x224 5 patchess, 10.4ms
# image 131/270 /content/neu_yolo/images/test/patches_4.jpg: 224x224 2 patchess, 12.7ms
# image 132/270 /content/neu_yolo/images/test/patches_45.jpg: 224x224 4 patchess, 8.8ms
# image 133/270 /content/neu_yolo/images/test/patches_47.jpg: 224x224 3 patchess, 10.5ms
# image 134/270 /content/neu_yolo/images/test/patches_49.jpg: 224x224 4 patchess, 11.3ms
# image 135/270 /content/neu_yolo/images/test/patches_51.jpg: 224x224 1 patches, 13.5ms
# image 136/270 /content/neu_yolo/images/test/patches_56.jpg: 224x224 4 patchess, 11.6ms
# image 137/270 /content/neu_yolo/images/test/patches_6.jpg: 224x224 3 patchess, 11.7ms
# image 138/270 /content/neu_yolo/images/test/patches_64.jpg: 224x224 1 patches, 11.7ms
# image 139/270 /content/neu_yolo/images/test/patches_65.jpg: 224x224 1 patches, 11.9ms
# image 140/270 /content/neu_yolo/images/test/patches_74.jpg: 224x224 1 inclusion, 6 patchess, 12.5ms
# image 141/270 /content/neu_yolo/images/test/patches_76.jpg: 224x224 3 patchess, 12.0ms
# image 142/270 /content/neu_yolo/images/test/patches_90.jpg: 224x224 3 patchess, 13.4ms
# image 143/270 /content/neu_yolo/images/test/patches_97.jpg: 224x224 2 patchess, 11.9ms
# image 144/270 /content/neu_yolo/images/test/pitted_surface_109.jpg: 224x224 2 pitted_surfaces, 10.0ms
# image 145/270 /content/neu_yolo/images/test/pitted_surface_126.jpg: 224x224 1 patches, 2 pitted_surfaces, 12.4ms
# image 146/270 /content/neu_yolo/images/test/pitted_surface_127.jpg: 224x224 2 pitted_surfaces, 11.1ms
# image 147/270 /content/neu_yolo/images/test/pitted_surface_129.jpg: 224x224 2 pitted_surfaces, 10.9ms
# image 148/270 /content/neu_yolo/images/test/pitted_surface_136.jpg: 224x224 1 pitted_surface, 10.0ms
# image 149/270 /content/neu_yolo/images/test/pitted_surface_143.jpg: 224x224 1 pitted_surface, 9.8ms
# image 150/270 /content/neu_yolo/images/test/pitted_surface_153.jpg: 224x224 1 pitted_surface, 10.9ms
# image 151/270 /content/neu_yolo/images/test/pitted_surface_162.jpg: 224x224 1 patches, 1 pitted_surface, 9.4ms
# image 152/270 /content/neu_yolo/images/test/pitted_surface_166.jpg: 224x224 2 pitted_surfaces, 10.8ms
# image 153/270 /content/neu_yolo/images/test/pitted_surface_18.jpg: 224x224 1 pitted_surface, 17.4ms
# image 154/270 /content/neu_yolo/images/test/pitted_surface_181.jpg: 224x224 2 pitted_surfaces, 12.4ms
# image 155/270 /content/neu_yolo/images/test/pitted_surface_184.jpg: 224x224 1 pitted_surface, 12.0ms
# image 156/270 /content/neu_yolo/images/test/pitted_surface_187.jpg: 224x224 3 pitted_surfaces, 13.4ms
# image 157/270 /content/neu_yolo/images/test/pitted_surface_190.jpg: 224x224 1 pitted_surface, 10.1ms
# image 158/270 /content/neu_yolo/images/test/pitted_surface_2.jpg: 224x224 2 pitted_surfaces, 6.5ms
# image 159/270 /content/neu_yolo/images/test/pitted_surface_209.jpg: 224x224 1 patches, 1 pitted_surface, 6.3ms
# image 160/270 /content/neu_yolo/images/test/pitted_surface_215.jpg: 224x224 1 pitted_surface, 8.8ms
# image 161/270 /content/neu_yolo/images/test/pitted_surface_227.jpg: 224x224 1 pitted_surface, 6.7ms
# image 162/270 /content/neu_yolo/images/test/pitted_surface_229.jpg: 224x224 3 pitted_surfaces, 6.1ms
# image 163/270 /content/neu_yolo/images/test/pitted_surface_231.jpg: 224x224 1 pitted_surface, 6.2ms
# image 164/270 /content/neu_yolo/images/test/pitted_surface_251.jpg: 224x224 1 pitted_surface, 6.9ms
# image 165/270 /content/neu_yolo/images/test/pitted_surface_256.jpg: 224x224 1 pitted_surface, 7.6ms
# image 166/270 /content/neu_yolo/images/test/pitted_surface_259.jpg: 224x224 1 pitted_surface, 6.3ms
# image 167/270 /content/neu_yolo/images/test/pitted_surface_266.jpg: 224x224 2 pitted_surfaces, 6.6ms
# image 168/270 /content/neu_yolo/images/test/pitted_surface_273.jpg: 224x224 2 pitted_surfaces, 6.9ms
# image 169/270 /content/neu_yolo/images/test/pitted_surface_275.jpg: 224x224 2 pitted_surfaces, 8.2ms
# image 170/270 /content/neu_yolo/images/test/pitted_surface_284.jpg: 224x224 1 pitted_surface, 7.4ms
# image 171/270 /content/neu_yolo/images/test/pitted_surface_36.jpg: 224x224 1 pitted_surface, 6.5ms
# image 172/270 /content/neu_yolo/images/test/pitted_surface_49.jpg: 224x224 1 pitted_surface, 6.3ms
# image 173/270 /content/neu_yolo/images/test/pitted_surface_61.jpg: 224x224 1 pitted_surface, 6.0ms
# image 174/270 /content/neu_yolo/images/test/pitted_surface_68.jpg: 224x224 2 pitted_surfaces, 5.9ms
# image 175/270 /content/neu_yolo/images/test/pitted_surface_77.jpg: 224x224 3 pitted_surfaces, 6.4ms
# image 176/270 /content/neu_yolo/images/test/pitted_surface_84.jpg: 224x224 2 pitted_surfaces, 6.1ms
# image 177/270 /content/neu_yolo/images/test/pitted_surface_89.jpg: 224x224 1 pitted_surface, 6.4ms
# image 178/270 /content/neu_yolo/images/test/pitted_surface_90.jpg: 224x224 1 pitted_surface, 6.6ms
# image 179/270 /content/neu_yolo/images/test/pitted_surface_93.jpg: 224x224 2 pitted_surfaces, 7.4ms
# image 180/270 /content/neu_yolo/images/test/pitted_surface_94.jpg: 224x224 2 pitted_surfaces, 9.4ms
# image 181/270 /content/neu_yolo/images/test/pitted_surface_97.jpg: 224x224 1 pitted_surface, 6.9ms
# image 182/270 /content/neu_yolo/images/test/rolled-in_scale_112.jpg: 224x224 2 rolled-in_scales, 6.7ms
# image 183/270 /content/neu_yolo/images/test/rolled-in_scale_121.jpg: 224x224 (no detections), 6.5ms
# image 184/270 /content/neu_yolo/images/test/rolled-in_scale_126.jpg: 224x224 3 rolled-in_scales, 7.1ms
# image 185/270 /content/neu_yolo/images/test/rolled-in_scale_134.jpg: 224x224 4 rolled-in_scales, 6.3ms
# image 186/270 /content/neu_yolo/images/test/rolled-in_scale_139.jpg: 224x224 2 rolled-in_scales, 6.6ms
# image 187/270 /content/neu_yolo/images/test/rolled-in_scale_145.jpg: 224x224 3 rolled-in_scales, 6.6ms
# image 188/270 /content/neu_yolo/images/test/rolled-in_scale_146.jpg: 224x224 2 rolled-in_scales, 6.5ms
# image 189/270 /content/neu_yolo/images/test/rolled-in_scale_157.jpg: 224x224 4 rolled-in_scales, 6.9ms
# image 190/270 /content/neu_yolo/images/test/rolled-in_scale_164.jpg: 224x224 1 rolled-in_scale, 10.2ms
# image 191/270 /content/neu_yolo/images/test/rolled-in_scale_171.jpg: 224x224 1 rolled-in_scale, 6.7ms
# image 192/270 /content/neu_yolo/images/test/rolled-in_scale_175.jpg: 224x224 2 rolled-in_scales, 6.8ms
# image 193/270 /content/neu_yolo/images/test/rolled-in_scale_177.jpg: 224x224 4 rolled-in_scales, 6.2ms
# image 194/270 /content/neu_yolo/images/test/rolled-in_scale_186.jpg: 224x224 3 rolled-in_scales, 8.1ms
# image 195/270 /content/neu_yolo/images/test/rolled-in_scale_187.jpg: 224x224 3 rolled-in_scales, 6.5ms
# image 196/270 /content/neu_yolo/images/test/rolled-in_scale_199.jpg: 224x224 2 rolled-in_scales, 6.9ms
# image 197/270 /content/neu_yolo/images/test/rolled-in_scale_209.jpg: 224x224 2 rolled-in_scales, 6.6ms
# image 198/270 /content/neu_yolo/images/test/rolled-in_scale_215.jpg: 224x224 3 rolled-in_scales, 6.7ms
# image 199/270 /content/neu_yolo/images/test/rolled-in_scale_216.jpg: 224x224 4 rolled-in_scales, 7.4ms
# image 200/270 /content/neu_yolo/images/test/rolled-in_scale_221.jpg: 224x224 2 rolled-in_scales, 9.5ms
# image 201/270 /content/neu_yolo/images/test/rolled-in_scale_224.jpg: 224x224 3 rolled-in_scales, 7.1ms
# image 202/270 /content/neu_yolo/images/test/rolled-in_scale_230.jpg: 224x224 3 rolled-in_scales, 6.1ms
# image 203/270 /content/neu_yolo/images/test/rolled-in_scale_232.jpg: 224x224 2 rolled-in_scales, 5.8ms
# image 204/270 /content/neu_yolo/images/test/rolled-in_scale_255.jpg: 224x224 1 rolled-in_scale, 6.7ms
# image 205/270 /content/neu_yolo/images/test/rolled-in_scale_258.jpg: 224x224 1 rolled-in_scale, 6.3ms
# image 206/270 /content/neu_yolo/images/test/rolled-in_scale_264.jpg: 224x224 2 rolled-in_scales, 6.4ms
# image 207/270 /content/neu_yolo/images/test/rolled-in_scale_282.jpg: 224x224 2 rolled-in_scales, 6.6ms
# image 208/270 /content/neu_yolo/images/test/rolled-in_scale_284.jpg: 224x224 2 rolled-in_scales, 6.2ms
# image 209/270 /content/neu_yolo/images/test/rolled-in_scale_292.jpg: 224x224 2 rolled-in_scales, 7.0ms
# image 210/270 /content/neu_yolo/images/test/rolled-in_scale_296.jpg: 224x224 1 rolled-in_scale, 6.5ms
# image 211/270 /content/neu_yolo/images/test/rolled-in_scale_36.jpg: 224x224 3 rolled-in_scales, 9.2ms
# image 212/270 /content/neu_yolo/images/test/rolled-in_scale_53.jpg: 224x224 3 rolled-in_scales, 9.6ms
# image 213/270 /content/neu_yolo/images/test/rolled-in_scale_68.jpg: 224x224 1 rolled-in_scale, 6.3ms
# image 214/270 /content/neu_yolo/images/test/rolled-in_scale_77.jpg: 224x224 3 rolled-in_scales, 6.5ms
# image 215/270 /content/neu_yolo/images/test/rolled-in_scale_94.jpg: 224x224 2 rolled-in_scales, 6.8ms
# image 216/270 /content/neu_yolo/images/test/scratches_101.jpg: 224x224 1 scratches, 6.8ms
# image 217/270 /content/neu_yolo/images/test/scratches_112.jpg: 224x224 3 inclusions, 1 scratches, 6.5ms
# image 218/270 /content/neu_yolo/images/test/scratches_113.jpg: 224x224 1 inclusion, 2 scratchess, 6.3ms
# image 219/270 /content/neu_yolo/images/test/scratches_121.jpg: 224x224 2 scratchess, 6.2ms
# image 220/270 /content/neu_yolo/images/test/scratches_127.jpg: 224x224 1 inclusion, 1 scratches, 5.9ms
# image 221/270 /content/neu_yolo/images/test/scratches_129.jpg: 224x224 2 inclusions, 1 scratches, 5.9ms
# image 222/270 /content/neu_yolo/images/test/scratches_132.jpg: 224x224 3 scratchess, 5.9ms
# image 223/270 /content/neu_yolo/images/test/scratches_136.jpg: 224x224 1 inclusion, 1 scratches, 6.1ms
# image 224/270 /content/neu_yolo/images/test/scratches_141.jpg: 224x224 5 inclusions, 1 scratches, 6.2ms
# image 225/270 /content/neu_yolo/images/test/scratches_142.jpg: 224x224 2 inclusions, 2 scratchess, 5.8ms
# image 226/270 /content/neu_yolo/images/test/scratches_147.jpg: 224x224 2 scratchess, 6.3ms
# image 227/270 /content/neu_yolo/images/test/scratches_148.jpg: 224x224 2 inclusions, 3 scratchess, 6.4ms
# image 228/270 /content/neu_yolo/images/test/scratches_151.jpg: 224x224 2 scratchess, 6.7ms
# image 229/270 /content/neu_yolo/images/test/scratches_155.jpg: 224x224 4 scratchess, 6.9ms
# image 230/270 /content/neu_yolo/images/test/scratches_158.jpg: 224x224 3 scratchess, 6.9ms
# image 231/270 /content/neu_yolo/images/test/scratches_167.jpg: 224x224 2 scratchess, 6.2ms
# image 232/270 /content/neu_yolo/images/test/scratches_18.jpg: 224x224 1 inclusion, 2 scratchess, 6.1ms
# image 233/270 /content/neu_yolo/images/test/scratches_181.jpg: 224x224 1 scratches, 9.5ms
# image 234/270 /content/neu_yolo/images/test/scratches_199.jpg: 224x224 2 scratchess, 7.0ms
# image 235/270 /content/neu_yolo/images/test/scratches_2.jpg: 224x224 2 scratchess, 6.9ms
# image 236/270 /content/neu_yolo/images/test/scratches_20.jpg: 224x224 1 scratches, 7.0ms
# image 237/270 /content/neu_yolo/images/test/scratches_201.jpg: 224x224 1 scratches, 8.9ms
# image 238/270 /content/neu_yolo/images/test/scratches_203.jpg: 224x224 1 inclusion, 2 scratchess, 6.4ms
# image 239/270 /content/neu_yolo/images/test/scratches_21.jpg: 224x224 4 scratchess, 6.1ms
# image 240/270 /content/neu_yolo/images/test/scratches_210.jpg: 224x224 4 scratchess, 10.2ms
# image 241/270 /content/neu_yolo/images/test/scratches_218.jpg: 224x224 4 scratchess, 11.0ms
# image 242/270 /content/neu_yolo/images/test/scratches_222.jpg: 224x224 1 inclusion, 4 scratchess, 7.8ms
# image 243/270 /content/neu_yolo/images/test/scratches_226.jpg: 224x224 4 scratchess, 6.3ms
# image 244/270 /content/neu_yolo/images/test/scratches_228.jpg: 224x224 1 scratches, 6.4ms
# image 245/270 /content/neu_yolo/images/test/scratches_231.jpg: 224x224 3 scratchess, 6.2ms
# image 246/270 /content/neu_yolo/images/test/scratches_238.jpg: 224x224 3 scratchess, 6.1ms
# image 247/270 /content/neu_yolo/images/test/scratches_242.jpg: 224x224 1 inclusion, 2 scratchess, 6.8ms
# image 248/270 /content/neu_yolo/images/test/scratches_25.jpg: 224x224 4 scratchess, 6.5ms
# image 249/270 /content/neu_yolo/images/test/scratches_261.jpg: 224x224 2 scratchess, 6.2ms
# image 250/270 /content/neu_yolo/images/test/scratches_265.jpg: 224x224 2 scratchess, 7.7ms
# image 251/270 /content/neu_yolo/images/test/scratches_27.jpg: 224x224 6 scratchess, 6.9ms
# image 252/270 /content/neu_yolo/images/test/scratches_276.jpg: 224x224 3 scratchess, 7.8ms
# image 253/270 /content/neu_yolo/images/test/scratches_288.jpg: 224x224 1 scratches, 9.6ms
# image 254/270 /content/neu_yolo/images/test/scratches_297.jpg: 224x224 4 scratchess, 6.6ms
# image 255/270 /content/neu_yolo/images/test/scratches_3.jpg: 224x224 4 scratchess, 6.7ms
# image 256/270 /content/neu_yolo/images/test/scratches_300.jpg: 224x224 2 scratchess, 6.3ms
# image 257/270 /content/neu_yolo/images/test/scratches_36.jpg: 224x224 1 scratches, 5.8ms
# image 258/270 /content/neu_yolo/images/test/scratches_4.jpg: 224x224 1 scratches, 6.1ms
# image 259/270 /content/neu_yolo/images/test/scratches_40.jpg: 224x224 1 scratches, 6.0ms
# image 260/270 /content/neu_yolo/images/test/scratches_41.jpg: 224x224 1 scratches, 6.6ms
# image 261/270 /content/neu_yolo/images/test/scratches_45.jpg: 224x224 1 scratches, 6.6ms
# image 262/270 /content/neu_yolo/images/test/scratches_46.jpg: 224x224 1 scratches, 6.4ms
# image 263/270 /content/neu_yolo/images/test/scratches_51.jpg: 224x224 1 scratches, 7.0ms
# image 264/270 /content/neu_yolo/images/test/scratches_55.jpg: 224x224 1 scratches, 9.4ms
# image 265/270 /content/neu_yolo/images/test/scratches_61.jpg: 224x224 1 scratches, 6.6ms
# image 266/270 /content/neu_yolo/images/test/scratches_62.jpg: 224x224 1 scratches, 6.7ms
# image 267/270 /content/neu_yolo/images/test/scratches_73.jpg: 224x224 1 scratches, 6.5ms
# image 268/270 /content/neu_yolo/images/test/scratches_86.jpg: 224x224 3 scratchess, 6.2ms
# image 269/270 /content/neu_yolo/images/test/scratches_91.jpg: 224x224 3 scratchess, 7.2ms
# image 270/270 /content/neu_yolo/images/test/scratches_96.jpg: 224x224 4 inclusions, 2 scratchess, 7.2ms
# Speed: 0.8ms preprocess, 8.4ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to /content/yolo_predictions/predictions

# %%
import shutil

shutil.copy(
    "/content/runs/neu_yolov8n/weights/best.pt",
    "/content/yolov8n_neu_defect_best.pt"
)
# Out:
# '/content/yolov8n_neu_defect_best.pt'

# %%
# !ls /content/yolov8n_neu_defect_best.pt
# Out:
# /content/yolov8n_neu_defect_best.pt

# %%
# !ls -lh /content/yolov8n_neu_defect_best.pt
# Out:
# -rw-r--r-- 1 root root 6.0M Sep 21 19:45 /content/yolov8n_neu_defect_best.pt

# %%
from google.colab import files
files.download("/content/yolov8n_neu_defect_best.pt")

# %%
# !find /content/yolo_predictions -type f | head
# Out:
# /content/yolo_predictions/predictions/patches_64.jpg
# /content/yolo_predictions/predictions/inclusion_219.jpg
# /content/yolo_predictions/predictions/scratches_199.jpg
# /content/yolo_predictions/predictions/inclusion_16.jpg
# /content/yolo_predictions/predictions/rolled-in_scale_224.jpg
# /content/yolo_predictions/predictions/rolled-in_scale_146.jpg
# /content/yolo_predictions/predictions/inclusion_272.jpg
# /content/yolo_predictions/predictions/inclusion_192.jpg
# /content/yolo_predictions/predictions/pitted_surface_190.jpg
# /content/yolo_predictions/predictions/patches_181.jpg

# %%
# !zip -r yolo_predictions.zip /content/yolo_predictions
# Out:
#   adding: content/yolo_predictions/ (stored 0%)
#   adding: content/yolo_predictions/predictions/ (stored 0%)
#   adding: content/yolo_predictions/predictions/patches_64.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/inclusion_219.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/scratches_199.jpg (deflated 4%)
#   adding: content/yolo_predictions/predictions/inclusion_16.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_224.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_146.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/inclusion_272.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/inclusion_192.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/pitted_surface_190.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/patches_181.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/crazing_232.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/patches_266.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/pitted_surface_181.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/patches_228.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_164.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/scratches_265.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/patches_194.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/pitted_surface_266.jpg (deflated 4%)
#   adding: content/yolo_predictions/predictions/patches_114.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/inclusion_239.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/patches_211.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_36.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/patches_235.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_139.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/scratches_158.jpg (deflated 4%)
#   adding: content/yolo_predictions/predictions/scratches_288.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/crazing_26.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_284.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/patches_128.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/crazing_272.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/scratches_18.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/patches_45.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/crazing_249.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/crazing_23.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/scratches_210.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/inclusion_237.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_221.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_126.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_53.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/patches_31.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/pitted_surface_284.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/inclusion_104.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/scratches_4.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/crazing_108.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/patches_138.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/patches_182.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/crazing_250.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/crazing_277.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/pitted_surface_97.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/inclusion_208.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/patches_16.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/patches_47.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/pitted_surface_259.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/scratches_25.jpg (deflated 4%)
#   adding: content/yolo_predictions/predictions/patches_261.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_77.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/inclusion_91.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/patches_270.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/patches_247.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_112.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/scratches_121.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/crazing_201.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/scratches_55.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/inclusion_88.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/patches_246.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/pitted_surface_49.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/scratches_300.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/inclusion_216.jpg (deflated 4%)
#   adding: content/yolo_predictions/predictions/inclusion_241.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/scratches_238.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/scratches_40.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/crazing_18.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/inclusion_218.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/crazing_300.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/scratches_101.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/patches_144.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/scratches_261.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/patches_76.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/patches_218.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_258.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/scratches_21.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/scratches_36.jpg (deflated 4%)
#   adding: content/yolo_predictions/predictions/pitted_surface_273.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/scratches_113.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/pitted_surface_143.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/inclusion_153.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_255.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/inclusion_36.jpg (deflated 4%)
#   adding: content/yolo_predictions/predictions/inclusion_71.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/inclusion_201.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_264.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_94.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/patches_74.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/crazing_294.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/patches_124.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/pitted_surface_227.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/inclusion_204.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/patches_233.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/scratches_41.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/pitted_surface_162.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_121.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/patches_200.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/crazing_284.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/pitted_surface_187.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/crazing_41.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/inclusion_130.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/scratches_147.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/patches_34.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/crazing_240.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/pitted_surface_68.jpg (deflated 4%)
#   adding: content/yolo_predictions/predictions/scratches_231.jpg (deflated 5%)
#   adding: content/yolo_predictions/predictions/patches_283.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/scratches_142.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/inclusion_263.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/crazing_65.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/scratches_276.jpg (deflated 4%)
#   adding: content/yolo_predictions/predictions/patches_56.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/pitted_surface_184.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/scratches_62.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/patches_174.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/scratches_148.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/crazing_28.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/crazing_122.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/crazing_79.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/crazing_145.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/crazing_254.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/inclusion_276.jpg (deflated 4%)
#   adding: content/yolo_predictions/predictions/pitted_surface_61.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/crazing_134.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_145.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/pitted_surface_18.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/crazing_89.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/patches_51.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/pitted_surface_209.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/scratches_242.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/crazing_237.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/pitted_surface_90.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/crazing_238.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/scratches_86.jpg (deflated 5%)
#   adding: content/yolo_predictions/predictions/inclusion_61.jpg (deflated 4%)
#   adding: content/yolo_predictions/predictions/scratches_27.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/crazing_269.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/pitted_surface_36.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_215.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_175.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_199.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/scratches_51.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/crazing_2.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/inclusion_67.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/patches_204.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/crazing_119.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/inclusion_134.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_282.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/pitted_surface_256.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/scratches_226.jpg (deflated 4%)
#   adding: content/yolo_predictions/predictions/pitted_surface_136.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_134.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/patches_90.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/patches_25.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/patches_260.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/patches_106.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/pitted_surface_93.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/crazing_172.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/crazing_285.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/patches_6.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/patches_213.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/patches_296.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/scratches_297.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/scratches_61.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/scratches_201.jpg (deflated 4%)
#   adding: content/yolo_predictions/predictions/patches_258.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/crazing_152.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/scratches_127.jpg (deflated 5%)
#   adding: content/yolo_predictions/predictions/inclusion_126.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/inclusion_283.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/pitted_surface_129.jpg (deflated 4%)
#   adding: content/yolo_predictions/predictions/scratches_73.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/inclusion_273.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/inclusion_224.jpg (deflated 5%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_157.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/crazing_88.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/scratches_203.jpg (deflated 5%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_177.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/inclusion_25.jpg (deflated 4%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_186.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/pitted_surface_127.jpg (deflated 4%)
#   adding: content/yolo_predictions/predictions/crazing_289.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/crazing_296.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/scratches_228.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/patches_170.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/inclusion_285.jpg (deflated 4%)
#   adding: content/yolo_predictions/predictions/scratches_96.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/pitted_surface_229.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/inclusion_7.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/scratches_129.jpg (deflated 6%)
#   adding: content/yolo_predictions/predictions/scratches_151.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/scratches_91.jpg (deflated 4%)
#   adding: content/yolo_predictions/predictions/scratches_112.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/pitted_surface_2.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_232.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/patches_4.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/pitted_surface_166.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/patches_115.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/patches_49.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/pitted_surface_89.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/patches_109.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/inclusion_75.jpg (deflated 6%)
#   adding: content/yolo_predictions/predictions/inclusion_59.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_187.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/scratches_3.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/patches_2.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/patches_97.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/crazing_59.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/crazing_63.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/pitted_surface_215.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/inclusion_51.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_216.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/pitted_surface_275.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_292.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/pitted_surface_94.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/pitted_surface_153.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/scratches_218.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/inclusion_17.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/inclusion_205.jpg (deflated 4%)
#   adding: content/yolo_predictions/predictions/scratches_222.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/inclusion_214.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/pitted_surface_77.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/patches_130.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/scratches_141.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/pitted_surface_126.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/scratches_45.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/pitted_surface_109.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/inclusion_3.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/scratches_46.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/pitted_surface_84.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/crazing_142.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/patches_284.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/scratches_181.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_209.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/scratches_155.jpg (deflated 5%)
#   adding: content/yolo_predictions/predictions/crazing_149.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/crazing_205.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/inclusion_11.jpg (deflated 5%)
#   adding: content/yolo_predictions/predictions/scratches_20.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/scratches_2.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/scratches_136.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/crazing_91.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_171.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_68.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/patches_250.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/patches_65.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/inclusion_245.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/patches_277.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/inclusion_289.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/pitted_surface_251.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/scratches_132.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/inclusion_1.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/crazing_113.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/crazing_214.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/patches_149.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/crazing_166.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/scratches_167.jpg (deflated 5%)
#   adding: content/yolo_predictions/predictions/patches_145.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_296.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/crazing_165.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/inclusion_53.jpg (deflated 3%)
#   adding: content/yolo_predictions/predictions/crazing_220.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/patches_121.jpg (deflated 1%)
#   adding: content/yolo_predictions/predictions/pitted_surface_231.jpg (deflated 2%)
#   adding: content/yolo_predictions/predictions/rolled-in_scale_230.jpg (deflated 2%)

# %%
# !pwd
# !ls -lh *.zip

# %%
from google.colab import files
files.download("/content/yolo_predictions.zip")

# %%
import shutil

shutil.make_archive(
    "/content/yolo_training_results",
    "zip",
    "/content/runs/neu_yolov8n"
)
# Out:
# '/content/yolo_training_results.zip'

# %%
from google.colab import files
files.download("/content/yolo_training_results.zip")
